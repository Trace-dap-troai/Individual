# %% [markdown]
# <a href="https://colab.research.google.com/github/Trace-dap-troai/Individual/blob/main/Week_2_ind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("week2_customer_transactions_messy.csv")
df.head()
# Out:
#   transaction_id customer_id transaction_date  amount currency payment_method  \
# 0          T0001        C100       2026-01-05  120.50      EUR           card
# 1          T0002        C101       2026/01/06    0.00      EUR           CARD
# 2          T0003        C102       06-01-2026  -35.00      USD  bank_transfer
# 3          T0004         NaN       2026-01-07  250.00      EUR           card
# 4          T0005        C104       2026-01-07   89.99     EURO           cash
#
#       status region last_updated
# 0  completed     DE   2026-01-05
# 1  completed     de   2026-01-20
# 2  completed     US   2026-01-07
# 3    pending     FR   2026-01-08
# 4  completed     DE   2026-01-09

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    11 non-null     object
#  1   customer_id       10 non-null     object
#  2   transaction_date  11 non-null     object
#  3   amount            10 non-null     float64
#  4   currency          11 non-null     object
#  5   payment_method    10 non-null     object
#  6   status            11 non-null     object
#  7   region            11 non-null     object
#  8   last_updated      10 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 924.0+ bytes
#                amount
# count       10.000000
# mean    100056.457000
# std     316207.939002
# min        -35.000000
# 25%         19.990000
# 50%         49.550000
# 75%        112.872500
# max    1000000.000000

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# customer_id         1
# transaction_date    0
# amount              1
# currency            0
# payment_method      1
# status              0
# region              0
# last_updated        1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df["amount"] <= 0]
# Out:
#   transaction_id customer_id transaction_date  amount currency payment_method  \
# 1          T0002        C101       2026/01/06     0.0      EUR           CARD
# 2          T0003        C102       06-01-2026   -35.0      USD  bank_transfer
#
#       status region last_updated
# 1  completed     de   2026-01-20
# 2  completed     US   2026-01-07

# %%
completeness = 1 - (df.isnull().sum().sum() / (df.shape[0] * df.shape[1]))
duplicate_rate = df.duplicated().sum() / len(df)
error_rate = len(df[df["amount"] <= 0]) / len(df)

completeness, duplicate_rate, error_rate
# Out:
# (np.float64(0.9595959595959596),
#  np.float64(0.09090909090909091),
#  0.18181818181818182)

# %% [markdown]
# Verification rules:
#
# 1. The amount must be greater than 0.
# 2. The customer code must not be blank.
# 3. The transaction code must be unique.

# %%
len(df[df["amount"] <= 0]), df.duplicated().sum(), df.isnull().sum().sum()
# Out:
# (2, np.int64(1), np.int64(4))

# %% [markdown]
# Suggested cleaning steps:
#
# - Remove duplicate records
# - Handle missing values
# - Correct invalid data
# - Normalize text
# - Convert date formats
